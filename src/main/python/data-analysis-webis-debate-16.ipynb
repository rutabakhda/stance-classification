# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Full Data

# %%
pathToData = "/home/weci2587/projects/wstud-visit-the-dome-ss19/data/demo/processed/webis-debate-16/full"
df = pd.DataFrame()
df["Document"] = np.nan
df["UnitsTotal"] = np.nan
df["Argumentative"] = np.nan
df["Non-Argumentative"] = np.nan
dirs = dir_list = next(os.walk(pathToData))[1]

for dir in dirs:
    documentPath = pathToData + "/" + dir
    total = 0
    argumentative = 0
    nonArgumentative = 0
    files = os.listdir(documentPath)
    for file in files:
        total += 1
        f = open(documentPath + "/" + file, "r")
        content = f.read()
        if "unitType=\"Non-Argumentative\"" in content:
            nonArgumentative += 1
        elif "unitType=\"Argumentative\"" in content:
            argumentative +=1 
        f.close()
    df = df.append({"Document": dir, "UnitsTotal": total, "Argumentative": argumentative, "Non-Argumentative": nonArgumentative},\
                  ignore_index = True)
df
# Out:
#          Document  UnitsTotal  Argumentative  Non-Argumentative
# 0     document-49        41.0           27.0               14.0
# 1    document-179        30.0            9.0               21.0
# 2    document-397        60.0           38.0               22.0
# 3     document-46        26.0           22.0                4.0
# 4    document-436        54.0           45.0                9.0
# 5     document-78        46.0           33.0               13.0
# 6     document-36        24.0           18.0                6.0
# 7     document-79        28.0           16.0               12.0
# 8    document-166        25.0           18.0                7.0
# 9    document-248        49.0           38.0               11.0
# 10   document-339        41.0           21.0               20.0
# 11     document-3        25.0           17.0                8.0
# 12    document-14        29.0           21.0                8.0
# 13    document-20        21.0           14.0                7.0
# ...

# %%
df.describe().T
# Out:
#                    count       mean        std  min   25%   50%   75%    max
# UnitsTotal         445.0  36.858427  13.350446  5.0  28.0  37.0  45.0  104.0
# Argumentative      445.0  24.373034  10.567253  0.0  18.0  24.0  30.0   72.0
# Non-Argumentative  445.0  12.485393   6.716786  0.0   7.0  12.0  16.0   42.0

# %%
df.sum()
# Out:
# Document             document-49document-179document-397document-46...
# UnitsTotal                                                       16402
# Argumentative                                                    10846
# Non-Argumentative                                                 5556
# dtype: object

# %% [markdown]
# # Training Data

# %%
pathToData = "/home/weci2587/projects/wstud-visit-the-dome-ss19/data/demo/processed/webis-debate-16/training-set-by-documents"
trainingData = pd.DataFrame()
trainingData["Document"] = np.nan
trainingData["UnitsTotal"] = np.nan
trainingData["Argumentative"] = np.nan
trainingData["Non-Argumentative"] = np.nan
dirs = dir_list = next(os.walk(pathToData))[1]

for dir in dirs:
    documentPath = pathToData + "/" + dir
    total = 0
    argumentative = 0
    nonArgumentative = 0
    files = os.listdir(documentPath)
    for file in files:
        total += 1
        f = open(documentPath + "/" + file, "r")
        content = f.read()
        if "unitType=\"Non-Argumentative\"" in content:
            nonArgumentative += 1
        elif "unitType=\"Argumentative\"" in content:
            argumentative +=1 
        f.close()
    trainingData = trainingData.append({"Document": dir, "UnitsTotal": total, "Argumentative": argumentative, "Non-Argumentative": nonArgumentative},\
                  ignore_index = True)
trainingData
# Out:
#          Document  UnitsTotal  Argumentative  Non-Argumentative
# 0    document-179        30.0            9.0               21.0
# 1    document-397        60.0           38.0               22.0
# 2     document-46        26.0           22.0                4.0
# 3    document-436        54.0           45.0                9.0
# 4     document-78        46.0           33.0               13.0
# 5     document-36        24.0           18.0                6.0
# 6     document-79        28.0           16.0               12.0
# 7    document-166        25.0           18.0                7.0
# 8    document-248        49.0           38.0               11.0
# 9    document-339        41.0           21.0               20.0
# 10     document-3        25.0           17.0                8.0
# 11    document-14        29.0           21.0                8.0
# 12    document-20        21.0           14.0                7.0
# 13   document-282        35.0           19.0               16.0
# ...

# %%
trainingData.describe().T
# Out:
#                    count       mean        std  min    25%   50%   75%    max
# UnitsTotal         356.0  36.867978  13.383908  5.0  28.00  36.5  46.0  104.0
# Argumentative      356.0  24.238764  10.461291  0.0  17.75  24.0  30.0   72.0
# Non-Argumentative  356.0  12.629213   6.771742  0.0   8.00  12.0  16.0   42.0

# %%
trainingData.sum()
# Out:
# Document             document-179document-397document-46document-43...
# UnitsTotal                                                       13125
# Argumentative                                                     8629
# Non-Argumentative                                                 4496
# dtype: object

# %% [markdown]
# # Test Data

# %%
pathToData = "/home/weci2587/projects/wstud-visit-the-dome-ss19/data/demo/processed/webis-debate-16/test-set-by-documents"
testData = pd.DataFrame()
testData["Document"] = np.nan
testData["UnitsTotal"] = np.nan
testData["Argumentative"] = np.nan
testData["Non-Argumentative"] = np.nan
dirs = dir_list = next(os.walk(pathToData))[1]

for dir in dirs:
    documentPath = pathToData + "/" + dir
    total = 0
    argumentative = 0
    nonArgumentative = 0
    files = os.listdir(documentPath)
    for file in files:
        total += 1
        f = open(documentPath + "/" + file, "r")
        content = f.read()
        if "unitType=\"Non-Argumentative\"" in content:
            nonArgumentative += 1
        elif "unitType=\"Argumentative\"" in content:
            argumentative +=1 
        f.close()
    testData = testData.append({"Document": dir, "UnitsTotal": total, "Argumentative": argumentative, "Non-Argumentative": nonArgumentative},\
                  ignore_index = True)
testData
# Out:
#         Document  UnitsTotal  Argumentative  Non-Argumentative
# 0    document-49        41.0           27.0               14.0
# 1   document-201        57.0           42.0               15.0
# 2   document-127        15.0           11.0                4.0
# 3   document-379        43.0           31.0               12.0
# 4   document-402        23.0           19.0                4.0
# 5   document-354        56.0           41.0               15.0
# 6    document-72        38.0           22.0               16.0
# 7   document-185        27.0           21.0                6.0
# 8   document-169        26.0           14.0               12.0
# 9   document-225        34.0           26.0                8.0
# 10  document-125        42.0           25.0               17.0
# 11  document-314        51.0           46.0                5.0
# 12  document-442        48.0           32.0               16.0
# 13  document-437        58.0           39.0               19.0
# ...

# %%
testData.describe().T
# Out:
#                    count       mean        std  min   25%   50%   75%   max
# UnitsTotal          89.0  36.820225  13.290942  5.0  27.0  37.0  44.0  69.0
# Argumentative       89.0  24.910112  11.025426  0.0  18.0  23.0  31.0  58.0
# Non-Argumentative   89.0  11.910112   6.497623  0.0   7.0  11.0  16.0  33.0

# %%
testData.sum()
# Out:
# Document             document-49document-201document-127document-37...
# UnitsTotal                                                        3277
# Argumentative                                                     2217
# Non-Argumentative                                                 1060
# dtype: object
